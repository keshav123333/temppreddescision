# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav123333/temppreddescision/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets --upgrade --quiet
import opendatasets as od

import os

import pandas as pd
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

sns.set_style('darkgrid')

# Configure Matplotlib settings
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.facecolor'] = '#000000'

# %%
url="https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package"
od.download(url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: keshavrai2004
# Your Kaggle Key:Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package
# Dataset URL: https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package
# ...
#   0%|          | 0.00/3.83M [00:00<?, ?B/s]
# ...
# 100%|██████████| 3.83M/3.83M [00:00<00:00, 4.21MB/s]
# 100%|██████████| 3.83M/3.83M [00:00<00:00, 4.21MB/s]

# %%
data="./weather-dataset-rattle-package"
os.listdir(data)
# Out:
# ['weatherAUS.csv']

# %%
traincsv=data+"/weatherAUS.csv"

# %%
raw_df=pd.read_csv(traincsv)
raw_df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
raw_df.dropna(subset=["RainToday","RainTomorrow"],inplace=True)

# %%
sns.countplot(x=pd.to_datetime(raw_df["Date"]).dt.year)
# Out:
# <Axes: xlabel='Date', ylabel='count'>

# %%
year=pd.to_datetime(raw_df["Date"]).dt.year
train_df=raw_df[year<2015]
val_df=raw_df[year==2015]
test_df=raw_df[year>2015]

# %%
input_cols=list(raw_df.columns)[1:-1]
target_cols="RainTomorrow"

train_inputs=train_df[input_cols]
train_targets=train_df[target_cols]
val_inputs=val_df[input_cols]
val_targets=val_df[target_cols]
test_inputs=test_df[input_cols]
test_targets=test_df[target_cols]

# %%
numeric_cols=train_inputs.select_dtypes(include=np.number).columns.tolist()
categorical_cols=train_inputs.select_dtypes("object").columns.tolist()
# so yaha tak toh apna categorical col numeric col alag kar liya

# %%
# now we will fix null values thing and data
train_inputs[numeric_cols].isna().sum().sort_values(ascending=False)
# Out:
# Sunshine         40046
# Evaporation      36331
# Cloud3pm         36022
# Cloud9am         34988
# Pressure3pm       9131
# Pressure9am       9112
# WindGustSpeed     6828
# Humidity3pm       1116
# WindSpeed3pm      1069
# Humidity9am       1052
# WindSpeed9am       874
# Temp3pm            596
# Temp9am            574
# MinTemp            314
# MaxTemp            187
# Rainfall             0
# dtype: int64
# Sunshine         40046
# Evaporation      36331
# Cloud3pm         36022
# Cloud9am         34988
# Pressure3pm       9131
# Pressure9am       9112
# WindGustSpeed     6828
# Humidity3pm       1116
# WindSpeed3pm      1069
# Humidity9am       1052
# WindSpeed9am       874
# Temp3pm            596
# Temp9am            574
# MinTemp            314
# MaxTemp            187
# Rainfall             0
# dtype: int64

# %%
# so to fix null values we will use imputer right so here we will compute or change the null values with some values
from sklearn.impute import SimpleImputer
# so here we will calculate numeric cols mean and then we will transform it to inputs ok
imputer=SimpleImputer(strategy="mean").fit(raw_df[numeric_cols])

train_inputs[numeric_cols]=imputer.transform(train_inputs[numeric_cols])
val_inputs[numeric_cols]=imputer.transform(val_inputs[numeric_cols])
test_inputs[numeric_cols]=imputer.transform(test_inputs[numeric_cols])
val_inputs.head()
# Out:
# <ipython-input-12-5423a7f7a36e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_inputs[numeric_cols]=imputer.transform(train_inputs[numeric_cols])
# <ipython-input-12-5423a7f7a36e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_inputs[numeric_cols]=imputer.transform(val_inputs[numeric_cols])
# <ipython-input-12-5423a7f7a36e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
raw_df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'MinTemp'}>,
#         <Axes: title={'center': 'MaxTemp'}>,
#         <Axes: title={'center': 'Rainfall'}>,
#         <Axes: title={'center': 'Evaporation'}>],
#        [<Axes: title={'center': 'Sunshine'}>,
#         <Axes: title={'center': 'WindGustSpeed'}>,
#         <Axes: title={'center': 'WindSpeed9am'}>,
#         <Axes: title={'center': 'WindSpeed3pm'}>],
#        [<Axes: title={'center': 'Humidity9am'}>,
#         <Axes: title={'center': 'Humidity3pm'}>,
#         <Axes: title={'center': 'Pressure9am'}>,
#         <Axes: title={'center': 'Pressure3pm'}>],
#        [<Axes: title={'center': 'Cloud9am'}>,
#         <Axes: title={'center': 'Cloud3pm'}>,
#         <Axes: title={'center': 'Temp9am'}>,
#         <Axes: title={'center': 'Temp3pm'}>]], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler().fit(raw_df[numeric_cols])
train_inputs[numeric_cols]=scaler.transform(train_inputs[numeric_cols])
val_inputs[numeric_cols]=scaler.transform(val_inputs[numeric_cols])
test_inputs[numeric_cols]=scaler.transform(test_inputs[numeric_cols])
# Out:
# <ipython-input-14-6f4b643ffc69>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_inputs[numeric_cols]=scaler.transform(train_inputs[numeric_cols])
# <ipython-input-14-6f4b643ffc69>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_inputs[numeric_cols]=scaler.transform(val_inputs[numeric_cols])
# <ipython-input-14-6f4b643ffc69>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
# yha hum nan ko handle karenge pehe
train_inputs[categorical_cols]=train_inputs[categorical_cols].fillna("Unknown")
val_inputs[categorical_cols]=val_inputs[categorical_cols].fillna("Unknown")
test_inputs[categorical_cols]=test_inputs[categorical_cols].fillna("Unknown")
encoder = OneHotEncoder(sparse_output=False, handle_unknown="ignore").fit(raw_df[categorical_cols])
# Out:
# <ipython-input-16-0879fc75c375>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_inputs[categorical_cols]=train_inputs[categorical_cols].fillna("Unknown")
# <ipython-input-16-0879fc75c375>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_inputs[categorical_cols]=val_inputs[categorical_cols].fillna("Unknown")
# <ipython-input-16-0879fc75c375>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
encoded_cols = list(encoder.get_feature_names_out(categorical_cols))
train_inputs[encoded_cols] = encoder.transform(train_inputs[categorical_cols])
val_inputs[encoded_cols] = encoder.transform(val_inputs[categorical_cols])
test_inputs[encoded_cols] = encoder.transform(test_inputs[categorical_cols])
# Out:
# <ipython-input-19-8cd9786a6c4e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_inputs[encoded_cols] = encoder.transform(train_inputs[categorical_cols])
# <ipython-input-19-8cd9786a6c4e>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_inputs[encoded_cols] = encoder.transform(train_inputs[categorical_cols])
# ...

# %%
x_train=train_inputs[numeric_cols+encoded_cols]
x_val=val_inputs[numeric_cols+encoded_cols]
x_test=test_inputs[numeric_cols+encoded_cols]
